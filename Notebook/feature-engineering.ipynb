# %%
import os
import sys
import pandas as pd
import logging
sys.path.append(os.path.abspath('../Scripts'))
import warnings
warnings.filterwarnings('ignore')

# %%
import feature as ft
import Eda as ed

# %%
df = 'merged_ecommerce_data.csv'
df = ed.load_data(df)
# Out:
# 2024-10-30 09:20:53,963 - INFO - Attempting to load data from merged_ecommerce_data.csv
# 2024-10-30 09:20:54,953 - INFO - Successfully loaded data from merged_ecommerce_data.csv

# %%
df
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0        247547  2015-06-28 03:00:34  2015-08-09 03:57:29              47
# 1        220737  2015-01-28 14:21:11  2015-02-11 20:28:28              15
# 2        390400  2015-03-19 20:49:09  2015-04-11 23:41:23              44
# 3         69592  2015-02-24 06:11:57  2015-05-23 16:40:14              55
# 4        174987  2015-07-07 12:58:11  2015-11-03 04:04:30              51
# ...         ...                  ...                  ...             ...
# 129141    33024  2015-04-12 21:07:04  2015-05-12 22:42:35              56
# 129142    62132  2015-08-07 10:46:59  2015-08-27 22:35:23              36
# 129143   363333  2015-02-09 07:56:12  2015-03-19 16:55:29              37
# 129144   340800  2015-05-10 19:31:22  2015-05-15 09:27:33               9
# 129145   244330  2015-01-31 03:06:13  2015-05-23 11:23:39              18
#
#             device_id  source  browser sex  age  ip_address  class  \
# ...

# %%
ft.create_time_features(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 ft.create_time_features(df)
#
# AttributeError: module 'feature' has no attribute 'create_time_features'
